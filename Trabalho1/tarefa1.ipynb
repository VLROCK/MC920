# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagem_mono_bab = cv2.imread('dataset/baboon_monocromatica.png',cv2.IMREAD_GRAYSCALE)

# %%
altura, largura = imagem_mono_bab.shape

imagem_90 = np.zeros((largura, altura))
i = np.arange(0,largura,1)
j = np.arange(0,altura,1)

imagem_90 = imagem_mono_bab.T

plt.imshow(imagem_90, cmap='gray')
