# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagem_mono_bab = cv2.imread('dataset/baboon_monocromatica.png',cv2.IMREAD_GRAYSCALE)

# %%
imagem_mono_bab = imagem_mono_bab / 255
g = 2


imagem_nova = imagem_mono_bab ** (1/g)

#imagem_nova = (imagem_nova * 255).astype(int)

plt.imshow(imagem_nova, cmap='gray')
