# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagem_mono_bab = cv2.imread('dataset/baboon_monocromatica.png',cv2.IMREAD_GRAYSCALE)

# %%
A = 120
imagem_mono_bab[imagem_mono_bab < A] = 0
imagem_mono_bab[imagem_mono_bab >= A] = 255

plt.imshow(imagem_mono_bab,cmap='gray')
plt.show()
