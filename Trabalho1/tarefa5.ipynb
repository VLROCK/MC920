# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagem1 = cv2.imread('dataset/baboon_monocromatica.png',cv2.IMREAD_GRAYSCALE)
imagem2 = cv2.imread('dataset/eraserhead.png',cv2.IMREAD_GRAYSCALE)
imagem3 = cv2.imread('dataset/o_farol.png',cv2.IMREAD_GRAYSCALE)

# %%
imagem = np.copy(imagem2)
A = 80
imagem[imagem <= A] = 0
imagem[imagem > A] = 255

plt.imshow(imagem,cmap='gray')
plt.imsave(f'imagens_transformadas/tarefa5/eraserhead_{A}.png', imagem, cmap='gray')
